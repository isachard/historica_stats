# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Mar 22 14:19:02 2020

@author: Isachard Rodriguez
"""

import pandas as pd
import glob as gl

df = pd.read_csv('mlb/datasets/atlanta.csv')
df.columns = ['Date', 'Team', 'Result', 'Score', 'PitcherF', 'PitcherL',
              'Pitcher H', 'Opponent PitcherF', 'Opponent PitcherL',
              'Opponent Pitcher H', 'Result Run Line', 'Run Line Value',
              'ResultTotal', 'Total Line', 'Total Value']

# print(df.to_string())





print('all csv files in data directory:', gl.glob('mlb/datasets/*.csv'))
for filename in gl.glob('mlb/datasets/*.csv'):
    data = pd.read_csv(filename)
    data.columns = ['Date', 'Team', 'Result', 'Score', 'PitcherF', 'PitcherL',
                    'Pitcher H', 'Opponent PitcherF', 'Opponent PitcherL',
                    'Opponent Pitcher H', 'Result Run Line', 'Run Line Value',
                    'ResultTotal', 'Total Line', 'Total Value']
    print(filename[13:-4])
    #print(data['ResultTotal'].value_counts())
    #print(data['ResultTotal'].value_counts().plot(kind='bar'))
    over = data.loc[data.ResultTotal == 'O', 'ResultTotal'].count()
    under = data.loc[data.ResultTotal == 'U', 'ResultTotal'].count()
    total_over_perc = round((over / (over + under)) *100,2)
    total_under_perc = round((under / (over + under)) *100,2)
    

        
    print( "Over: " + str(total_over_perc))
    print("Under: " + str(total_under_perc))
    print()
# Out:
# all csv files in data directory: ['mlb/datasets\\arizona.csv', 'mlb/datasets\\atlanta.csv', 'mlb/datasets\\baltimore.csv', 'mlb/datasets\\boston.csv', 'mlb/datasets\\chicagocubs.csv', 'mlb/datasets\\chicagowhitesox.csv', 'mlb/datasets\\cincinnati.csv', 'mlb/datasets\\cleveland.csv', 'mlb/datasets\\colorado.csv', 'mlb/datasets\\detroit.csv', 'mlb/datasets\\houston.csv', 'mlb/datasets\\kansascity.csv', 'mlb/datasets\\losangelesangels.csv', 'mlb/datasets\\losangelesdodgers.csv', 'mlb/datasets\\miami.csv', 'mlb/datasets\\milwaukee.csv', 'mlb/datasets\\minnesota.csv', 'mlb/datasets\\newyorkmets.csv', 'mlb/datasets\\newyorkyankees.csv', 'mlb/datasets\\oakland.csv', 'mlb/datasets\\philadelphia.csv', 'mlb/datasets\\pittsburgh.csv', 'mlb/datasets\\sandiego.csv', 'mlb/datasets\\sanfrancisco.csv', 'mlb/datasets\\seattle.csv', 'mlb/datasets\\stlouis.csv', 'mlb/datasets\\tampabay.csv', 'mlb/datasets\\texas.csv', 'mlb/datasets\\toronto.csv', 'mlb/datasets\\washington.csv']
# arizona
# Over: 47.06
# Under: 52.94
#
# atlanta
# Over: 51.28
# Under: 48.72
#
# baltimore
# Over: 50.96
# Under: 49.04
#
# boston
# Over: 45.81
# Under: 54.19
#
# chicagocubs
# Over: 49.35
# Under: 50.65
#
# chicagowhitesox
# Over: 49.03
# Under: 50.97
#
# cincinnati
# Over: 53.55
# Under: 46.45
#
# cleveland
# Over: 40.4
# Under: 59.6
#
# colorado
# Over: 41.56
# Under: 58.44
#
# detroit
# Over: 56.49
# Under: 43.51
#
# houston
# Over: 53.29
# Under: 46.71
#
# kansascity
# Over: 48.39
# Under: 51.61
#
# losangelesangels
# Over: 45.7
# Under: 54.3
#
# losangelesdodgers
# Over: 50.0
# Under: 50.0
#
# miami
# Over: 55.33
# Under: 44.67
#
# milwaukee
# Over: 44.16
# Under: 55.84
#
# minnesota
# Over: 48.34
# Under: 51.66
#
# newyorkmets
# Over: 59.73
# Under: 40.27
#
# newyorkyankees
# Over: 52.53
# Under: 47.47
#
# oakland
# Over: 53.85
# Under: 46.15
#
# philadelphia
# Over: 47.62
# Under: 52.38
#
# pittsburgh
# Over: 40.26
# Under: 59.74
#
# sandiego
# Over: 52.29
# Under: 47.71
#
# sanfrancisco
# Over: 48.99
# Under: 51.01
#
# seattle
# Over: 49.03
# Under: 50.97
#
# stlouis
# Over: 52.94
# Under: 47.06
#
# tampabay
# Over: 49.37
# Under: 50.63
#
# texas
# Over: 47.74
# Under: 52.26
#
# toronto
# Over: 47.4
# Under: 52.6
#
# washington
# Over: 45.33
# Under: 54.67
